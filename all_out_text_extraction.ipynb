# %% [markdown]
# <a href="https://colab.research.google.com/github/taofiqsulayman/collab-playground/blob/main/all_out_text_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain
# !pip install langchain-community
# !pip install unstructured
# !pip install pdfminer.six
# !pip install pypdf
# !pip install pillow
# !pip install pillow-heif
# !pip install unstructured[local-inference] # Install the required dependencies
# !pip install popler
# !pip install poppler-utils

# !sudo apt-get install poppler-utils # Make sure poppler utilities are installed
# !sudo apt-get install tesseract-ocr
# !pip install pytesseract
import pytesseract
import os
os.environ['PATH'] += ':/usr/bin'
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 375.2 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 997.8/997.8 kB 20.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.9/394.9 kB 16.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.1/149.1 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 28.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 2.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# langchain csv loader

# %%
from langchain_community.document_loaders import CSVLoader

loader = CSVLoader(file_path='./sample_data/test_csv.csv')
data = loader.load()

# for doc in data:
#     print(doc.page_content)

print(data[0].metadata)
print(data[0].page_content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_loaders/csv_loader.py in lazy_load(self)
#     128         try:
# --> 129             with open(self.file_path, newline="", encoding=self.encoding) as csvfile:
#     130                 yield from self.__read_file(csvfile)
#
# FileNotFoundError: [Errno 2] No such file or directory: './sample_data/test_csv.csv'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-2-a325fc41afae> in <cell line: 4>()
#       2
#       3 loader = CSVLoader(file_path='./sample_data/test_csv.csv')
# ----> 4 data = loader.load()
#       5
#       6 # for doc in data:
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/document_loaders/base.py in load(self)
# ...

# %% [markdown]
# Unstructured file loader via langchain

# %%
from langchain_community.document_loaders import UnstructuredFileLoader

loader = UnstructuredFileLoader('./sample_data/SamScanned.pdf')
data = loader.load()

# for doc in data:
#     print(doc.page_content)

print(data[0].page_content)

# %%
# !apt-get install libreoffice
# !pip install "unstructured[all-docs]"
from langchain_community.document_loaders import UnstructuredWordDocumentLoader

loader = UnstructuredWordDocumentLoader('./sample.doc')
data = loader.load()

print(data)

# for doc in data:
#     print(doc.page_content)
# Out:
# ...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-d608b8f92103> in <cell line: 6>()
#       4
#       5 loader = UnstructuredWordDocumentLoader('./sample.doc')
# ----> 6 data = loader.load()
#       7
#       8 print(data)
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/document_loaders/base.py in load(self)
#      28     def load(self) -> List[Document]:
#      29         """Load data into Document objects."""
# ---> 30         return list(self.lazy_load())
#      31
#      32     async def aload(self) -> List[Document]:
#
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_loaders/unstructured.py in lazy_load(self)
#     105     def lazy_load(self) -> Iterator[Document]:
#     106         """Load file."""
# --> 107         elements = self._get_elements()
#     108         self._post_process_elements(elements)
# ...

# %%
from langchain_community.document_loaders import UnstructuredFileLoader

loader = UnstructuredFileLoader('./sample_data/SophiaScanned.pdf')
data = loader.load()

# for doc in data:
#     print(doc.page_content)

print(data[0].page_content)

# %%
from langchain_community.document_loaders import UnstructuredPDFLoader

loader = UnstructuredPDFLoader('./sample_data/SophiaScanned.pdf')
data = loader.load()

# for doc in data:
#     print(doc.page_content)

print(data[0].page_content)

# %%
from langchain_community.document_loaders import UnstructuredPDFLoader

loader = UnstructuredPDFLoader('./sample_data/national-capitals.pdf')
data = loader.load()

# for doc in data:
#     print(doc.page_content)

print(data[0].page_content)

# %% [markdown]
# PyPDF via langchain

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader('./sample_data/SophiaScanned.pdf')
data = loader.load()

# for doc in data:
#     print(doc.page_content)

print(data[0].page_content)

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader('./sample_data/national-capitals.pdf')
data = loader.load()

# for doc in data:
#     print(doc.page_content)

print(data[0].page_content)

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader('./sample_data/table.pdf')
data = loader.load()

# for doc in data:
#     print(doc.page_content)

print(data[0].page_content)

# %% [markdown]
# Apache Tika

# %%
# !pip install tika

import tika
tika.initVM()
from tika import parser
parsed = parser.from_file('./sample_data/table.pdf')
print(parsed["metadata"])
print(parsed["content"])

# %%
import tika
tika.initVM()
from tika import parser
parsed = parser.from_file('./sample_data/national-capitals.pdf')
print(parsed["metadata"])
print(parsed["content"])

# %%
os.environ['PYTHONIOENCODING'] = 'utf8'

import tika
from tika import parser
parsed = parser.from_file('./sample_data/SophiaScanned.pdf')
print(parsed["content"])

# %%
import tika
from tika import parser
parsed = parser.from_file('./sample_data/SamScanned.pdf')
print(parsed["content"])

# %% [markdown]
# Hotpdf

# %%
! pip install hotpdf

# %%
from hotpdf import HotPdf

doc = HotPdf('./sample_data/JS.pdf')
data = doc.extract_page_text(0)

print(data)

# %%
# !pip install tika

import tika
tika.initVM()
from tika import parser
parsed = parser.from_file('./sample.jpg')
print(parsed["metadata"])
print(parsed)
# Out:
# ...
# {'Transparency Alpha': 'nonpremultipled', 'X-TIKA:Parsed-By-Full-Set': ['org.apache.tika.parser.DefaultParser', 'org.apache.tika.parser.image.ImageParser', 'org.apache.tika.parser.ocr.TesseractOCRParser'], 'X-TIKA:content_handler': 'ToTextContentHandler', 'tiff:ImageLength': '1400', 'Compression CompressionTypeName': 'deflate', 'Data BitsPerSample': '8 8 8 8', 'Data PlanarConfiguration': 'PixelInterleaved', 'Dimension VerticalPixelSize': '0.35273367', 'IHDR': 'width=990, height=1400, bitDepth=8, colorType=RGBAlpha, compressionMethod=deflate, filterMethod=adaptive, interlaceMethod=none', 'Chroma ColorSpaceType': 'RGB', 'Content-Length': '239703', 'tiff:BitsPerSample': '8 8 8 8', 'Content-Type': 'image/png', 'height': '1400', 'pHYs': 'pixelsPerUnitXAxis=2835, pixelsPerUnitYAxis=2835, unitSpecifier=meter', 'Dimension PixelAspectRatio': '1.0', 'resourceName': "b'sample.jpg'", 'Compression NumProgressiveScans': '1', 'Content-Type-Parser-Override': 'image/ocr-png', 'X-TIKA:Parsed-By': ['or
# ...

# %%
import os
os.environ['PYTHONIOENCODING'] = 'utf8'

import tika
from tika import parser
parsed = parser.from_file('./sample.jpg')
print(parsed["content"])
# Out:
# Sophia Worthington
#
# PR Specialist
#
# ‘Address 56 Uxbridge Road Linkedin linkedin.comvin/sophia-}-worthington
# WS SBW ‘Twitter twitter.com/sophieworthington22
# London
#
# Phone 07700 900556
#
# E-mail sophia.worthington@gmail.com
#
# WWW sophie-insights.com
#
# Senior PR specialist with 9+ years of experience in marketing and corporate public relations. Pitched press releases to the most
#
# prominent industry magazines to secure over 20 mentions a month in top media outlets. Managed multiple PR and marketing annual
# budgets from £5,000 to £300,000. Helped increase clients’ annual sales by up to 40%.
#
# Experience
#
# 2013-03 - present
#
# 2009-06 - 2013-03
#
# 2008-08 - 2009-06
#
# Education
#
# 2007-09 - 2008-07
#
# Senior PR Spe
#
# Berkadia, London
#
#
#
# ist
#
# + Developed and implemented policies and procedures for overall public relations effort in cooperation with sales
# and customer service teams.
#
# ...

# %%
from langchain_community.document_loaders import UnstructuredFileLoader

loader = UnstructuredFileLoader('./sample.png')
data = loader.load()

# for doc in data:
#     print(doc.page_content)

print(data[0].page_content)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:141: LangChainDeprecationWarning: The class `UnstructuredFileLoader` was deprecated in LangChain 0.2.8 and will be removed in 0.4.0. An updated version of the class exists in the langchain-unstructured package and should be used instead. To use it run `pip install -U langchain-unstructured` and import as `from langchain_unstructured import UnstructuredLoader`.
#   warn_deprecated(
# yolox_l0.05.onnx:   0%|          | 0.00/217M [00:00<?, ?B/s]
# Sophia Worthington
#
# PR Specialist
#
# Address 56 Uxbridge Road
#
# LinkedIn linkedin.com/in/sophia-j-worthington
#
# WS SBW
#
# Twitter twitter.com/sophieworthington22
#
# London
#
# Phone 07700 900556
#
# E-mail sophia.worthington@gmail.com
#
# WWW sophie-insights.com
#
# ...

# %%
# !pip install Spire.Doc
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 20.3 MB/s eta 0:00:00
# ...

# %%
from spire.doc import *
from spire.doc.common import *

# Create word document
document = Document()

# Load a doc or docx file
document.LoadFromFile("./sample.doc")

print(document.GetText())

#Save the document to PDF
# document.SaveToFile("ToPDF.pdf", FileFormat.PDF)
# document.Close()
# Out:
# Evaluation Warning: The document was created with Spire.Doc for Python.
# Lorem ipsum
#
#   Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nunc ac faucibus odio.
#
# Vestibulum neque massa, scelerisque sit amet ligula eu, congue molestie mi. Praesent ut varius sem. Nullam at porttitor arcu, nec lacinia nisi. Ut ac dolor vitae odio interdum condimentum. Vivamus dapibus sodales ex, vitae malesuada ipsum cursus convallis. Maecenas sed egestas nulla, ac condimentum orci. Mauris diam felis, vulputate ac suscipit et, iaculis non est. Curabitur semper arcu ac ligula semper, nec luctus nisl blandit. Integer lacinia ante ac libero lobortis imperdiet. Nullam mollis convallis ipsum, ac accumsan nunc vehicula vitae. Nulla eget justo in felis tristique fringilla. Morbi sit amet tortor quis risus auctor condimentum. Morbi in ullamcorper elit. Nulla iaculis tellus sit amet mauris tempus fringilla.
# Maecenas mauris lectus, lobortis et purus mattis, blandit dictum tellus.
# ...

# %% [markdown]
# PADDLE OCR WITH PYMUPDF

# %%
# !pip install paddlepaddle paddleocr pymupdf pillow

# %%
import fitz  # PyMuPDF
from paddleocr import PaddleOCR
from PIL import Image
from io import BytesIO
from multiprocessing import Pool, cpu_count
import numpy as np # Import numpy

# Initialize PaddleOCR
ocr = PaddleOCR(use_angle_cls=True, lang='en')

def extract_text_from_pages_single_threaded(pdf_path):
    extracted_text = ""
    doc = fitz.open(pdf_path)
    num_pages = doc.page_count
    for i in range(num_pages):
        page = doc.load_page(i)
        text = page.get_text("text")
        if not text.strip():
            text = extract_text_with_paddleocr(pdf_path, pages=[i])
        extracted_text += text
    return extracted_text

def extract_text_from_page_indices(pdf_path, indices):
    extracted_text = ""
    doc = fitz.open(pdf_path)
    for i in indices:
        page = doc.load_page(i)
        text = page.get_text("text")
        if not text.strip():
            text = extract_text_with_paddleocr(pdf_path, pages=[i])
        extracted_text += text
    return extracted_text

def extract_text_with_paddleocr(pdf_path, pages=None):
    extracted_text = ""
    doc = fitz.open(pdf_path)
    page_range = range(doc.page_count) if pages is None else pages
    for i in page_range:
        page = doc.load_page(i)
        pix = page.get_pixmap()
        image = Image.open(BytesIO(pix.tobytes(output="png")))
        result = ocr.ocr(np.array(image), slice=False) # Convert the PIL Image object to a NumPy array
        # The OCR result contains a list of tuples. Each tuple represents a detected text box with coordinates and text.
        # Extract the text from the tuples.
        text = "\n".join([line[-1][0] for line in result[0]])
        extracted_text += text
    return extracted_text

def parallel_text_extraction(pdf_path, num_pages):
    cpu = cpu_count()
    seg_size = int(num_pages / cpu + 1)
    indices = [range(i * seg_size, min((i + 1) * seg_size, num_pages)) for i in range(cpu)]
    with Pool() as pool:
        results = pool.starmap(extract_text_from_page_indices, [(pdf_path, idx) for idx in indices])
    combined_text = "".join(results)
    return combined_text

def process_pdf(file_path):
    doc = fitz.open(file_path)
    num_pages = doc.page_count
    if num_pages < 10:
        extracted_text = extract_text_from_pages_single_threaded(file_path)
    else:
        extracted_text = parallel_text_extraction(file_path, num_pages)
    return extracted_text

def text_to_markdown(text):
    markdown_text = ""
    for line in text.split("\n"):
        markdown_text += f"{line}\n\n"
    return markdown_text
# Out:
# [2024/09/14 02:11:22] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec
# ...

# %%
# Example usage
pdf_path = './inv1.pdf'
extracted_text = process_pdf(pdf_path)
markdown_text = text_to_markdown(extracted_text)

print(extracted_text)

# Save to a Markdown file
with open('output.md', 'w') as f:
    f.write(markdown_text)
# Out:
# [2024/09/14 02:11:46] ppocr DEBUG: dt_boxes num : 96, elapsed : 0.42404603958129883
# [2024/09/14 02:11:46] ppocr DEBUG: cls num  : 96, elapsed : 0.3618662357330322
# [2024/09/14 02:11:54] ppocr DEBUG: rec_res num  : 96, elapsed : 7.880767822265625
# [2024/09/14 02:11:54] ppocr DEBUG: dt_boxes num : 71, elapsed : 0.21959614753723145
# [2024/09/14 02:11:55] ppocr DEBUG: cls num  : 71, elapsed : 0.2563626766204834
# [2024/09/14 02:11:58] ppocr DEBUG: rec_res num  : 71, elapsed : 3.8689208030700684
# [2024/09/14 02:11:59] ppocr DEBUG: dt_boxes num : 62, elapsed : 0.19714951515197754
# [2024/09/14 02:11:59] ppocr DEBUG: cls num  : 62, elapsed : 0.23037147521972656
# [2024/09/14 02:12:06] ppocr DEBUG: rec_res num  : 62, elapsed : 6.7786853313446045
# [Your Company Name]
# INVOICE
# [Street Address, City, State, ZIP Code]
# Tax ID:
# [Phone]
# 123456789
# [Email]
# Invoice Date
# XX.XX.XX
# [Name]
# Invoice No.
# 1227
# [ob Position]
# Billing through:
# ...

# %%
pdf_path = './sample1.pdf'
extracted_text = process_pdf(pdf_path)
markdown_text = text_to_markdown(extracted_text)

print(markdown_text)
# Out:
# DOCUMENT RESUME
#
# ED 121 193
#
# HE 007 640
#
# AUTHOR
#
# Weinstock, Ruth
#
# TITLE
#
# British Open University: Media Used in Context.
#
# INSTITUTION
#
# Educational Facilities Labs., Inc., Nev York, N.Y.:
#
# Society for Coll. and Univ. Planning, New York,
#
# N.Y.
#
# PUB DATE
#
# Apr 75
#
# NOTE
#
# 7p.
#
# AVAILABLE FROM
#
# Society for College and University Planning, 3
#
# Washington Square Village, Suite 1-A, New York, Nev
#
# York 10012 ($1.00)
#
# JOURNAL CIT
#
# Planning for Higher Education: v4 n2:3/5 Apr 1975
#
# EDRS PRICE
#
# MF-$0.83 HC-$1.67 Plus Postage
#
# DESCRIPTORS
#
# Academic Achievement: Cost Effectiveness; *Curriculum
#
# Development: *Educational Innovation: *External
#
# Degree Programs: *Higher Education; Independent
#
# Study: Instructional Innovation; *Media Selection;
#
# Progressive Education
#
# IDENTIFIERS
#
# *Open University
#
# ABSTRACT
#
# The experience of an open university with the uses of
#
# ...

# %%
pdf_path = './sample2.pdf'
extracted_text = process_pdf(pdf_path)
markdown_text = text_to_markdown(extracted_text)

print(markdown_text)
# Out:
# [2024/09/13 22:03:16] ppocr DEBUG: dt_boxes num : 45, elapsed : 0.5286915302276611
# [2024/09/13 22:03:16] ppocr DEBUG: cls num  : 45, elapsed : 0.25350284576416016
# [2024/09/13 22:03:38] ppocr DEBUG: rec_res num  : 45, elapsed : 22.026386499404907
# [2024/09/13 22:03:39] ppocr DEBUG: dt_boxes num : 39, elapsed : 0.19706249237060547
# [2024/09/13 22:03:39] ppocr DEBUG: cls num  : 39, elapsed : 0.1068572998046875
# [2024/09/13 22:03:49] ppocr DEBUG: rec_res num  : 39, elapsed : 9.912042140960693
# [2024/09/13 22:03:49] ppocr DEBUG: dt_boxes num : 15, elapsed : 0.17679738998413086
# [2024/09/13 22:03:49] ppocr DEBUG: cls num  : 15, elapsed : 0.04578804969787598
# [2024/09/13 22:03:51] ppocr DEBUG: rec_res num  : 15, elapsed : 2.023552179336548
# [2024/09/13 22:03:51] ppocr DEBUG: dt_boxes num : 70, elapsed : 0.19484472274780273
# [2024/09/13 22:03:52] ppocr DEBUG: cls num  : 70, elapsed : 0.22470831871032715
# ...

# %%
file1 = './table.pdf'
file2 = './national-capitals.pdf'

md1 = process_pdf(file1)
md2 = process_pdf(file2)

markdown_text1 = text_to_markdown(md1)
markdown_text2 = text_to_markdown(md2)

print(markdown_text1)
print('----------')
print(markdown_text2)
# Out:
# Example table
#
# This is an example of a data table.
#
# Disability
#
# Category
#
# Participants
#
# Ballots
#
# Completed
#
# Ballots
#
# Incomplete/
#
# Terminated
#
# Results
#
# Accuracy
#
# Time to
#
# complete
#
# Blind
#
# 5
#
# 1
#
# 4
#
# 34.5%, n=1
#
# 1199 sec, n=1
#
# Low Vision
#
# 5
#
# 2
#
# 3
#
# 98.3% n=2
#
# (97.7%, n=3)
#
# 1716 sec, n=3
#
# (1934 sec, n=2)
#
# Dexterity
#
# 5
#
# 4
#
# 1
#
# 98.3%, n=4
#
# 1672.1 sec, n=4
#
# Mobility
#
# 3
#
# 3
#
# 0
#
# 95.4%, n=3
#
# 1416 sec, n=3
#
#
#
#
#
#
# ----------
# Country
#
# Capital
#
# Population
#
#   %
#
# Year
#
# World Capital Cities
#
# Percent "%" is city population as a percentage of the country, as of "Year".
#
# Afghanistan
#
# Kabul
#
# 4601789
#
# 11.5% 2021
#
# Albania
#
# Tirana
#
# 557422
#
# 19.5% 2011
#
# Algeria
#
# Algiers
#
# 3915811
#
# 8.9% 2011
#
# American Samoa (USA)
#
# Pago Pago
#
# 3656
#
# 8.1% 2010
#
# Andorra
#
# Andorra la Vella
#
# 22873
#
# 28.9% 2022
#
# Angola
#
# Luanda
#
# ...

# %% [markdown]
# Pymupdf4llm

# %%
# !pip install pymupdf4llm

# %%
import pymupdf4llm

file1 = './sample1.pdf'
file2 = './sample2.pdf'

# md3 = pymupdf4llm.to_markdown(file1)
md4 = pymupdf4llm.to_markdown(file2)

# print(md3)
print(md4)
# Out:
# Processing ./sample2.pdf...
# ]
# -----
#
# -----
#
# -----
#
# -----
#
# -----
#
# -----
#
# -----
#
# -----

# %%
import pymupdf4llm

file1 = './table.pdf'
file2 = './national-capitals.pdf'

md3 = pymupdf4llm.to_markdown(file1)
md4 = pymupdf4llm.to_markdown(file2)

print(md3)
print('----------')
print(md4)
# Out:
# Processing ./table.pdf...
# ]
# Processing ./national-capitals.pdf...
# ]
# ## Example table
# # This is an example of a data table.
#
# |Disability Category|Participants|Ballots Completed|Ballots Incomplete/ Terminated|Results|Col6|
# |---|---|---|---|---|---|
# |||||Accuracy|Time to complete|
# |Blind|5|1|4|34.5%, n=1|1199 sec, n=1|
# |Low Vision|5|2|3|98.3% n=2 (97.7%, n=3)|1716 sec, n=3 (1934 sec, n=2)|
# |Dexterity|5|4|1|98.3%, n=4|1672.1 sec, n=4|
# |Mobility|3|3|0|95.4%, n=3|1416 sec, n=3|
#
#
# -----
#
#
# ----------
# # World Capital Cities
#
# _Percent "%" is city population as a percentage of the country, as of "Year"._
#
# |Country|Capital|Population|%|Year|
# |---|---|---|---|---|
# |Afghanistan|Kabul|4601789|11.5%|2021|
# |Albania|Tirana|557422|19.5%|2011|
# |Algeria|Algiers|3915811|8.9%|2011|
# |American Samoa (USA)|Pago Pago|3656|8.1%|2010|
# |Andorra|Andorra la Vella|22873|28.9%|2022|
# |Angola|Luanda|2571861|7.5%|2020|
# |Anguilla (UK)|The Valley|1067|6.8%|2011|
# ...

# %%
import fitz  # PyMuPDF
from paddleocr import PaddleOCR
# from PIL import Image
from io import BytesIO
from multiprocessing import Pool, cpu_count
import numpy as np # Import numpy
import pymupdf4llm
from PIL import Image, ImageOps, ImageEnhance # Import the ImageOps module


# Initialize PaddleOCR
ocr = PaddleOCR(use_angle_cls=True, lang='en')

def extract_text_from_pages_single_threaded(pdf_path):
    extracted_text = ""
    doc = fitz.open(pdf_path)
    num_pages = doc.page_count
    for i in range(num_pages):
        page = doc.load_page(i)
        check_text = page.get_text("text")
        text = pymupdf4llm.to_markdown(pdf_path, pages=[i])
        if not check_text.strip():
            text = extract_text_with_paddleocr(pdf_path, pages=[i])
        extracted_text += text
    return extracted_text

def extract_text_from_page_indices(pdf_path, indices):
    extracted_text = ""
    doc = fitz.open(pdf_path)
    for i in indices:
        page = doc.load_page(i)
        check_text = page.get_text("text")
        text = pymupdf4llm.to_markdown(pdf_path, pages=[i])
        if not check_text.strip():
            text = extract_text_with_paddleocr(pdf_path, pages=[i])
        extracted_text += text
    return extracted_text

def enhance_image(image):
    """Enhance the image quality to improve OCR accuracy."""
    # Convert to grayscale
    image = ImageOps.grayscale(image)

    # Apply sharpening
    enhancer = ImageEnhance.Sharpness(image)
    image = enhancer.enhance(2.0)

    # Apply contrast enhancement
    enhancer = ImageEnhance.Contrast(image)
    image = enhancer.enhance(1.5)

    # Apply brightness enhancement
    enhancer = ImageEnhance.Brightness(image)
    image = enhancer.enhance(1.5)

    return image

def extract_text_with_paddleocr(pdf_path, pages=None):
    """Extract text from PDF using OCR (PaddleOCR) and convert it to Markdown."""
    extracted_text = ""
    doc = fitz.open(pdf_path)
    page_range = range(doc.page_count) if pages is None else pages

    for i in page_range:
        page = doc.load_page(i)
        pix = page.get_pixmap()  # Get image of the page
        image = Image.open(BytesIO(pix.tobytes(output="png")))

        # Enhance the image for better OCR results
        enhanced_image = enhance_image(image)

        # Run OCR on the enhanced image
        result = ocr.ocr(np.array(enhanced_image), slice=False)

        # Extract recognized text and format it as Markdown
        text = "\n".join([line[-1][0] for line in result[0]])
        markdown_text = text_to_markdown(text)  # Convert OCR result to Markdown

        extracted_text += text
    return extracted_text

def parallel_text_extraction(pdf_path, num_pages):
    cpu = cpu_count()
    seg_size = int(num_pages / cpu + 1)
    indices = [range(i * seg_size, min((i + 1) * seg_size, num_pages)) for i in range(cpu)]
    with Pool() as pool:
        results = pool.starmap(extract_text_from_page_indices, [(pdf_path, idx) for idx in indices])
    combined_text = "".join(results)
    return combined_text

def process_pdf(file_path):
    doc = fitz.open(file_path)
    num_pages = doc.page_count
    if num_pages < 10:
        extracted_text = extract_text_from_pages_single_threaded(file_path)
    else:
        extracted_text = parallel_text_extraction(file_path, num_pages)
    return extracted_text

def text_to_markdown(text):
    markdown_text = ""
    for line in text.split("\n"):
        markdown_text += f"{line}\n\n"
    return markdown_text
# Out:
# [2024/09/14 02:52:59] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec
# ...

# %%
file1 = './table.pdf'
file2 = './national-capitals.pdf'
file3 = './inv1.pdf'
file4 = './sample1.pdf'
file5 = './sample2.pdf'
file6 = './RSScanned.pdf'

# md1 = process_pdf(file1)
# md2 = process_pdf(file2)
md3 = process_pdf(file3)
# md4 = process_pdf(file4)
# md5 = process_pdf(file5)
# md6 = process_pdf(file6)

# print(md1)
# print('----------')
# print(md2)
# print('----------')
print(md3)
# print('----------')
# # print(md4)
# # print('----------')
# print(md5)
# print('----------')
# print(md6)
# Out:
# Processing ./inv1.pdf...
# ]
# [2024/09/14 02:48:53] ppocr DEBUG: dt_boxes num : 96, elapsed : 0.32386016845703125
# [2024/09/14 02:48:53] ppocr DEBUG: cls num  : 96, elapsed : 0.3497328758239746
# [2024/09/14 02:48:58] ppocr DEBUG: rec_res num  : 96, elapsed : 5.226823329925537
# Processing ./inv1.pdf...
# ]
# [2024/09/14 02:48:59] ppocr DEBUG: dt_boxes num : 71, elapsed : 0.23439502716064453
# [2024/09/14 02:48:59] ppocr DEBUG: cls num  : 71, elapsed : 0.2711024284362793
# [2024/09/14 02:49:04] ppocr DEBUG: rec_res num  : 71, elapsed : 4.551635026931763
# Processing ./inv1.pdf...
# ]
# [2024/09/14 02:49:05] ppocr DEBUG: dt_boxes num : 62, elapsed : 0.302232027053833
# [2024/09/14 02:49:05] ppocr DEBUG: cls num  : 62, elapsed : 0.36145567893981934
# [2024/09/14 02:49:10] ppocr DEBUG: rec_res num  : 62, elapsed : 4.552138805389404
# [Your Company Name]
# INVOICE
# [Street Address,CityState,ZIP Code
# Tax ID:
# [Phone]
# 123456789
# [Email]
# Invoice Date
# XX.XX.XX
# [Name]
# ...
